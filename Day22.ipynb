# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import numpy as np
df = pd.read_excel(r'C:\Users\lenki\Documents\code\30daycharchallenge\day88.xlsx')
print (df)
# Out:
#                          Mammal  Weight
# 0                    Blue whale  136000
# 1                       Bowhead  100000
# 2                     Fin whale   70000
# 3          Southern right whale   45000
# 4                Humpback whale   30000
# ...                         ...     ...
# 1212       Lesser horseshoe bat       0
# 1213      Long-tailed planigale       0
# 1214             Cinereus shrew       0
# 1215               Black myotis       0
# 1216  White-toothed pygmy shrew       0
#
# [1217 rows x 2 columns]

# %%
df_sorted = df.sort_values(by='Weight', ascending=False)
df_sorted
# Out:
#                          Mammal  Weight
# 1                    Blue whale  136000
# 2                       Bowhead  100000
# 3                     Fin whale   70000
# 4          Southern right whale   45000
# 5                Humpback whale   30000
# ...                         ...     ...
# 891          Philippine tarsier       0
# 890         European water vole       0
# 889       Carpentarian rock rat       0
# 888             Western tarsier       0
# 1217  White-toothed pygmy shrew       0
#
# [1217 rows x 2 columns]

# %%
df.dtypes
import plotly.io as pio

# %%
fig = px.scatter(df_sorted, df.index, y='Weight', animation_frame=df_sorted.index, log_x=True,
 log_y=True, hover_name='Mammal', title="Mammal body weight (kg)", width=400, height=400,)
fig.update_layout(template="plotly_dark")

fig.update_xaxes(range=[0, 3.3])
fig.update_yaxes(range=[0, 5.2])
                 


fig.update_layout(xaxis_title="#30DayChartChallenge | Day 8 & 22 | Alenka Gucek",
                #| Data: https://thewebsiteofeverything.com/animals/mammals/adult-weight.html"
                  font=dict(
        family="Courier New, monospace",
        size=8,
        color="White"
                 ))

fig.show()
#fig.write_image("images/day8.jpg")
#fig.write_html("images/day8.html")
# Out:
# <div>                            <div id="e7655c5f-8fb1-4a15-933f-fca01fee2e8e" class="plotly-graph-div" style="height:400px; width:400px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e7655c5f-8fb1-4a15-933f-fca01fee2e8e")) {                    Plotly.newPlot(                        "e7655c5f-8fb1-4a15-933f-fca01fee2e8e",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>index=1<br>x=%{x}<br>Weight=%{y}<extra></extra>", "hovertext": ["Blue whale"], "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": [1], "xaxis": "x", "y": [136000], "yaxis": "y"}],                        {"font": {"color": "White", "family": "Courier New, monospace", "size": 8}, "height": 400, "legend": 
# ...
